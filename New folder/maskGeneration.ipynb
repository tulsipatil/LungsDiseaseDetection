# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# Define paths
BASE_PATH = "C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/organized_dataset copy"
OUTPUT_PATH = "C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2"

# Ensure output directories exist
os.makedirs(os.path.join(OUTPUT_PATH, "normal"), exist_ok=True)
os.makedirs(os.path.join(OUTPUT_PATH, "pneumonia"), exist_ok=True)

def margin(img, margin_percent=10):
    """Crop 10% margins from all sides."""
    h, w = img.shape
    margin_x = int(w * margin_percent / 100)
    margin_y = int(h * margin_percent / 100)
    return img[margin_y:h-margin_y, margin_x:w-margin_x]

def process(img):
    """Apply KMeans clustering for segmentation."""
    flat_img = img.flatten().reshape(-1, 1)
    kmeans = KMeans(n_clusters=2, n_init=10, random_state=0)
    labels = kmeans.fit_predict(flat_img)
    centers = kmeans.cluster_centers_
    
    if np.mean(centers[1]) > np.mean(centers[0]):
        labels = 1 - labels

    return np.reshape(labels, img.shape) * 255  # Convert to binary mask

def segment_and_filter(clustered_img):
    """Extract the two largest contours (lungs)."""
    clustered_img = clustered_img.astype(np.uint8)
    _, thresh = cv2.threshold(clustered_img, 0, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    contours = sorted(contours, key=cv2.contourArea, reverse=True)[:2]  # Select 2 largest contours

    result = np.zeros_like(clustered_img)
    cv2.drawContours(result, contours, -1, 255, thickness=cv2.FILLED)
    return result, contours

def calculate_trapezium_area(top_width, bottom_width, height):
    """Calculate the area of the trapezium."""
    return 0.5 * (top_width + bottom_width) * height

def detect_and_plot_trapezium(processed_img):
    """Fit a trapezium around the largest lung contours and calculate area."""
    color_image = cv2.cvtColor(processed_img, cv2.COLOR_GRAY2BGR)
    _, binary_image = cv2.threshold(processed_img, 1, 255, cv2.THRESH_BINARY)
    contours, _ = cv2.findContours(binary_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    if len(contours) < 2:
        return color_image  # Skip if fewer than 2 contours

    contours = sorted(contours, key=cv2.contourArea, reverse=True)[:2]
    combined_rect = cv2.boundingRect(np.concatenate(contours))

    # Expand bounding rectangle for margin
    x, y, w, h = combined_rect
    combined_rect = (x - 20, y - 20, w + 40, h + 40)

    # Define trapezium points
    combined_trapezium_pts = np.array([
        (combined_rect[0], combined_rect[1] + combined_rect[3]),  # Bottom-left
        (combined_rect[0] + combined_rect[2], combined_rect[1] + combined_rect[3]),  # Bottom-right
        (combined_rect[0] + int(combined_rect[2] * 0.75), combined_rect[1]),  # Top-right
        (combined_rect[0] + int(combined_rect[2] * 0.25), combined_rect[1])  # Top-left
    ], np.int32)

    # Draw trapezium
    # cv2.polylines(color_image, [combined_trapezium_pts], isClosed=True, color=(0, 0, 255), thickness=3)

    # Calculate trapezium area
    top_width = combined_rect[2] * 0.5
    bottom_width = combined_rect[2]
    height = combined_rect[3]
    area = calculate_trapezium_area(top_width, bottom_width, height)

    print(f"Trapezium Area: {area:.2f}")

    return color_image

def process_image(image_path):
    """Process a single image."""
    img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if img is None:
        print(f"Skipping {image_path}, unable to load image.")
        return None

    cropped_img = margin(img)
    clustered_img = process(cropped_img)
    filtered_result, largest_contours = segment_and_filter(clustered_img)

    # Mirror left lung to right lung
    half_width = filtered_result.shape[1] // 2
    mirrored_half = cv2.flip(filtered_result[:, :half_width], 1)
    joined_image = cv2.hconcat([filtered_result[:, :half_width], mirrored_half])

    # Apply trapezium detection and visualization
    final_image = detect_and_plot_trapezium(joined_image)

    return final_image

def process_all_images():
    """Iterate through both folders and process all images."""
    for category in ["normal", "pneumonia"]:
        input_folder = os.path.join(BASE_PATH, category)
        output_folder = os.path.join(OUTPUT_PATH, category)

        for filename in os.listdir(input_folder):
            if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
                image_path = os.path.join(input_folder, filename)
                processed_image = process_image(image_path)

                if processed_image is not None:
                    output_path = os.path.join(output_folder, filename)
                    cv2.imwrite(output_path, processed_image)
                    print(f"Saved: {output_path}")

# Run the processing function
process_all_images()
# Out:
# Trapezium Area: 958369.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\aug_0_9997.jpeg
# Trapezium Area: 1046272.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0001-0001.jpeg
# Trapezium Area: 1454520.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0003-0001.jpeg
# Trapezium Area: 1684009.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0005-0001.jpeg
# Trapezium Area: 1108672.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0006-0001.jpeg
# Trapezium Area: 1864497.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0007-0001.jpeg
# Trapezium Area: 1167390.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0009-0001.jpeg
# Trapezium Area: 1252746.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0010-0001.jpeg
# Trapezium Area: 1924258.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0011-0001-0001.jpeg
# Trapezium Area: 1945902.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0011-0001-0002.jpeg
# Trapezium Area: 1441800.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0011-0001.jpeg
# Trapezium Area: 2417167.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0013-0001.jpeg
# Trapezium Area: 1040256.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0015-0001.jpeg
# Trapezium Area: 2185969.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0016-0001.jpeg
# Trapezium Area: 1538637.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0017-0001.jpeg
# Trapezium Area: 1257784.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0019-0001.jpeg
# Trapezium Area: 2356140.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0021-0001.jpeg
# Trapezium Area: 363532.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0022-0001.jpeg
# Trapezium Area: 1156332.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0023-0001.jpeg
# Trapezium Area: 2577744.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0025-0001.jpeg
# Trapezium Area: 1934208.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0027-0001.jpeg
# Trapezium Area: 2101119.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0028-0001.jpeg
# Trapezium Area: 2516431.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0029-0001.jpeg
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0030-0001.jpeg
# Trapezium Area: 1421376.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0031-0001.jpeg
# Trapezium Area: 2135196.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0033-0001-0001.jpeg
# Trapezium Area: 1879950.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0033-0001-0002.jpeg
# Trapezium Area: 1300968.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0033-0001.jpeg
# Trapezium Area: 2477124.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0035-0001.jpeg
# Trapezium Area: 1609344.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0036-0001.jpeg
# Trapezium Area: 1316724.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0037-0001.jpeg
# Trapezium Area: 1821054.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0039-0001.jpeg
# Trapezium Area: 2110219.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0041-0001.jpeg
# Trapezium Area: 2346561.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0043-0001.jpeg
# Trapezium Area: 2971542.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0045-0001.jpeg
# Trapezium Area: 1645518.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0046-0001.jpeg
# Trapezium Area: 800532.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0049-0001.jpeg
# Trapezium Area: 1619878.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0050-0001.jpeg
# Trapezium Area: 688810.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0059-0001.jpeg
# Trapezium Area: 1094544.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0061-0001.jpeg
# Trapezium Area: 1605033.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0063-0001.jpeg
# Trapezium Area: 722925.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0065-0001.jpeg
# Trapezium Area: 585189.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-0067-0001.jpeg
# Trapezium Area: 1066333.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\normal\IM-
00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person145_virus_294.jpeg
# Trapezium Area: 294984.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person145_virus_295.jpeg
# Trapezium Area: 377982.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1460_bacteria_3801.jpeg
# Trapezium Area: 477954.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1460_bacteria_3805.jpeg
# Trapezium Area: 487390.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1460_virus_2507.jpeg
# Trapezium Area: 602692.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1460_virus_2509.jpeg
# Trapezium Area: 890010.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1461_virus_2510.jpeg
# Trapezium Area: 1196694.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1462_virus_2512.jpeg
# Trapezium Area: 519750.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1463_bacteria_3808.jpeg
# Trapezium Area: 635815.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1463_bacteria_3809.jpeg
# Trapezium Area: 563040.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1463_bacteria_3811.jpeg
# Trapezium Area: 409920.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1463_virus_2516.jpeg
# Trapezium Area: 305976.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1465_virus_2530.jpeg
# Trapezium Area: 408240.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1465_virus_2531.jpeg
# Trapezium Area: 559884.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1465_virus_2532.jpeg
# Trapezium Area: 548625.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1465_virus_2537.jpeg
# Trapezium Area: 336996.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1466_virus_2541.jpeg
# Trapezium Area: 275409.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1466_virus_2542.jpeg
# Trapezium Area: 438444.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1466_virus_2543.jpeg
# Trapezium Area: 316302.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1467_virus_2544.jpeg
# Trapezium Area: 584512.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1468_bacteria_3822.jpeg
# Trapezium Area: 969228.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1468_virus_2545.jpeg
# Trapezium Area: 1037518.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1468_virus_2546.jpeg
# Trapezium Area: 255834.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1469_bacteria_3824.jpeg
# Trapezium Area: 311304.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1469_bacteria_3827.jpeg
# Trapezium Area: 928867.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1469_virus_2547.jpeg
# Trapezium Area: 404257.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person146_bacteria_700.jpeg
# Trapezium Area: 258930.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person146_bacteria_703.jpeg
# Trapezium Area: 402505.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person146_bacteria_704.jpeg
# Trapezium Area: 575280.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person146_virus_296.jpeg
# Trapezium Area: 286452.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1470_bacteria_3829.jpeg
# Trapezium Area: 224541.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1470_bacteria_3830.jpeg
# Trapezium Area: 255780.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1471_bacteria_3831.jpeg
# Trapezium Area: 741600.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1471_virus_2549.jpeg
# Trapezium Area: 6610.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1472_bacteria_3833.jpeg
# Trapezium Area: 546984.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1472_bacteria_3834.jpeg
# Trapezium Area: 540886.50
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1472_virus_2550.jpeg
# Trapezium Area: 294984.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1473_bacteria_3836.jpeg
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1473_virus_2551.jpeg
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1473_virus_2553.jpeg
# Trapezium Area: 236898.00
# Saved: C:/Users/tulsi/Desktop/Pneumonia-Detection-using-Deep-Learning - Copy/mask2\pneumonia\person1474_bacteria_3837.jpeg
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 125
#     122                     print(f"Saved: {output_path}")
#     124 # Run the processing function
# --> 125 process_all_images()
#
# Cell In[2], line 117, in process_all_images()
#     115 if filename.lower().endswith(('.jpg', '.jpeg', '.png')):
#     116     image_path = os.path.join(input_folder, filename)
# --> 117     processed_image = process_image(image_path)
#     119     if processed_image is not None:
#     120         output_path = os.path.join(output_folder, filename)
#
# Cell In[2], line 95, in process_image(image_path)
#      92     return None
#      94 cropped_img = margin(img)
# ---> 95 clustered_img = process(cropped_img)
#      96 filtered_result, largest_contours = segment_and_filter(clustered_img)
#      98 # Mirror left lung to right lung
#
# Cell In[2], line 26, in process(img)
#      24 flat_img = img.flatten().reshape(-1, 1)
#      25 kmeans = KMeans(n_clusters=2, n_init=10, random_state=0)
# ---> 26 labels = kmeans.fit_predict(flat_img)
#      27 centers = kmeans.cluster_centers_
#      29 if np.mean(centers[1]) > np.mean(centers[0]):
#
# File c:\Users\tulsi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1033, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1010 def fit_predict(self, X, y=None, sample_weight=None):
#    1011     """Compute cluster centers and predict cluster index for each sample.
#    1012
#    1013     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#    1031         Index of the cluster each sample belongs to.
#    1032     """
# -> 1033     return self.fit(X, sample_weight=sample_weight).labels_
#
# File c:\Users\tulsi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1461, in KMeans.fit(self, X, y, sample_weight)
#    1457 best_inertia, best_labels = None, None
#    1459 for i in range(self._n_init):
#    1460     # Initialize centers
# -> 1461     centers_init = self._init_centroids(
#    1462         X, x_squared_norms=x_squared_norms, init=init, random_state=random_state
#    1463     )
#    1464     if self.verbose:
#    1465         print("Initialization complete")
#
# File c:\Users\tulsi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:989, in _BaseKMeans._init_centroids(self, X, x_squared_norms, init, random_state, init_size, n_centroids)
#     986     n_samples = X.shape[0]
#     988 if isinstance(init, str) and init == "k-means++":
# --> 989     centers, _ = _kmeans_plusplus(
#     990         X,
#     991         n_clusters,
#     992         random_state=random_state,
#     993         x_squared_norms=x_squared_norms,
#     994     )
#     995 elif isinstance(init, str) and init == "random":
#     996     seeds = random_state.permutation(n_samples)[:n_clusters]
#
# File c:\Users\tulsi\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:234, in _kmeans_plusplus(X, n_clusters, x_squared_norms, random_state, n_local_trials)
#     231 np.clip(candidate_ids, None, closest_dist_sq.size - 1, out=candidate_ids)
#     233 # Compute distances to center candidates
# --> 234 distance_to_candidates = _euclidean_distances(
#     235     X[candidate_ids], X, Y_norm_squared=x_squared_norms, squared=True
#     236 )
#     238 # update closest distances squared and potential for each candidate
#     239 np.minimum(closest_dist_sq, distance_to_candidates, out=distance_to_candidates)
#
# File c:\Users\tulsi\anaconda3\Lib\site-packages\sklearn\metrics\pairwise.py:369, in _euclidean_distances(X, Y, X_norm_squared, Y_norm_squared, squared)
#     366     distances = _euclidean_distances_upcast(X, XX, Y, YY)
#     367 else:
#     368     # if dtype is already float64, no need to chunk and upcast
# --> 369     distances = -2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     370     distances += XX
#     371     distances += YY
#
# File c:\Users\tulsi\anaconda3\Lib\site-packages\sklearn\utils\extmath.py:192, in safe_sparse_dot(a, b, dense_output)
#     188 else:
#     189     ret = a @ b
#     191 if (
# --> 192     sparse.issparse(a)
#     193     and sparse.issparse(b)
#     194     and dense_output
#     195     and hasattr(ret, "toarray")
#     196 ):
#     197     return ret.toarray()
#     198 return ret
#
# File c:\Users\tulsi\anaconda3\Lib\site-packages\scipy\sparse\_base.py:1461, in issparse(x)
#    1456     pass
#    1458 sparray.__doc__ = _spbase.__doc__
# -> 1461 def issparse(x):
#    1462     """Is `x` of a sparse array type?
#    1463
#    1464     Parameters
#    (...)
#    1485     False
#    1486     """
#    1487     return isinstance(x, _spbase)
#
# KeyboardInterrupt:
